# %% [markdown]
# # Workshop Programeren en AI
#
# ## **Basis Python**
#
# We beginnen eerst met de basisprincipes van Python, hierin nemen we jullie kort mee in hoe je nou een code kunt opstellen en mee te werk kunt gaan.
#
# ### **Variabelen**
# In python gebruiken we continu Variabelen. Variabelen moet je zien als een soort doosje waarin je iets kunt opslaan – zoals een getal, tekst, of lijst. Je geeft dat doosje een naam, zodat je het later makkelijk kunt gebruiken. In Python gebruiken vervolgens deze variabelen om bijvoorbeeld resultaten op te slaan, of simpelweg een stuk tekst. Voorbeeld:
#
# ```Python
# bedrijf = "Division Q"
# leeftijd = 2
# ```
#
# In het voorbeeld hierboven slaan we de tekst "Division Q" op in de variabele bedrijf, en het getal 2 in de variabele leeftijd. Een belangrijke opmerking hierbij is dat de variabel naam geen spatie mag bevatten, oftewel: bedrijf 2 = "Koppert Cress" zal een error geven. De juiste manier van werken is om een lagestreep te gebruiken en kleine letters, oftewel: bedrijf\_2 = "Koppert Cress" is de correcte manier. Bij het kiezen van de variabel naam, vermijd niets zeggende namen, probeer altijd zo duidelijk en specifiek mogelijk te zijn!
#
# een andere belangrijke opmerking voor variabelen is dat niet alle informatie is hetzelfde soort. Daarom gebruikt Python datatypes.
# __________

# %% [markdown]
# ### **Datatypes**
# In Python (en in andere programmeertalen) werken we met de zojuist uitgelegde variabelen. Deze gegevens kunnen verschillende soorten zijn. De soort noemen we een datatype.
# Je kunt het vergelijken met dingen in het echte leven:
#
# * Een getal is iets anders dan een stuk tekst.
# * Een lijst met boodschappen is iets anders dan een waar/niet waar antwoord.
#
# Python moet weten met wat voor soort gegevens je werkt. Daarom gebruiken wij verschillende datatypes, de belangrijkste zijn:
# - **Integers --** Hele getallen     &nbsp;&nbsp;&nbsp;&nbsp; (bijv. 365)
# - **Float --** Getal met komma      &nbsp;&nbsp; (bijv. 3.14)
# - **String --** Tekst               &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; (bijv. "Hallo")
# - **Bool --** Waar of niet waar     &nbsp;&nbsp;&nbsp; (True en False)
#
# Maar computers zijn niet heel slim:

# %%
print(f"floats doen niet altijd wat je verwacht:      0.1 + 0.2 = {0.1 + 0.2}")
print(f'Let goed op met welke datatypes je werkt:   "1" + "1" = "{"1" + "1"}"')
# Out:
# floats doen niet altijd wat je verwacht:      0.1 + 0.2 = 0.30000000000000004
# Let goed op met welke datatypes je werkt:   "1" + "1" = "11"

# %% [markdown]
# _______________
# ### **Datastructures**
#
# Naast datatypes gebruiken we ook _datastructures_, oftewel een groepering van verschillende variable. De belangrijkste zijn:
#
# #### **list:** lijst van integers/floats/strings/bools/etc.
# in dit voorbeeld kunnen we variabelen uit de lijst halen door hem weer op te splitsen in variabelen.
# oftewel als we nu print(a) doen, krijgen we de waarde 1
#
# ```Python
# my_list = [1, 2, 3]
# a, b, c = my_list
# ```
#
#
# #### **dictionary:** waarde koppelen aan een sleutel
# In dit voorbeeld maken we een dictionary met drie sleutels, je kan waardes ophalen uit de dictionary met een sleutel. <br>In deze dictionary:
# - "naam" is een sleutel → "Bo" is de waarde
# - "leeftijd" is een sleutel → 24 is de waarde
# - "is\_werknemer\_van\_de\_maand" is een sleutel → True is de waarde
# - "werkt_aan" is een sleutel -> [...] is de waarde
#
# ```Python
# persoon = {
#     "naam": "Bo",
#     "leeftijd": 24,
#     "is_werknemer_van_de_maand": True
#     "werkt_aan": ["corridor", "CUT project"]
# }
# print(persoon["naam"])  # -> Bo
# ```
# --------------------------------------------------------

# %% [markdown]
# Je weet nu dat je in Python:
#
# * Gegevens kunt opslaan in variabelen
# * Dat deze gegevens een bepaald datatype hebben (zoals getallen, tekst, lijsten, of een dictionary)
#
# Nu gaan we verder met logica en herhaling in je code, hiervoor gebruiken we `if-else statements` (voor keuzes) en `for loops` (voor herhaling).
#
# #### **If-else statements**
# Soms wil je dat je programma iets anders doet afhankelijk van een situatie. Bijvoorbeeld: Als iemand ouder is dan 18, dan mag die persoon stemmen.
# Dat kan je doen met een if (als), elif (anders als), en else (anders).
#
# ```Python
# leeftijd = 20
# if leeftijd >= 18:
#     print("Je mag stemmen!")
# else:
#     print("Je bent nog te jong om te stemmen.")
# ```
#
# Wat gebeurd er in deze code? <br> Als leeftijd groter of gelijk is aan 18, dan wordt het eerste stuk code uitgevoerd. Anders doet Python wat er onder 'else' staat. <br>
#
# Mochten er meerdere keuzes zijn dan gebruiken we 'elif', bijvoorbeeld als we erachter willen komen in welke voetbal categorie iemand volgend jaar moet voetballen.
#
# ```Python
# leeftijd = 15
# if leeftijd <= 19:
#     print("JO19")
# elif leeftijd <= 14:
#     print("JO14")
# elif leeftijd <= 8:
#     print("JO9")
# else:
#     print("Senioren")
# ```
#
# #### **For-loop**
# Een for loop laat je iets voor een bepaald aantal keer herhalen, bijvoorbeeld voor elk item in een lijst.
# ```Python
# boodschappen = ["melk", "brood", "kaas"]
# for item in boodschappen:
#     print(item)
# ```
#
# Wat gebeurd er in deze code?<br> De lijst boodschappen bevat 3 dingen. De for loop kijkt één voor één naar elk item in de lijst en voert print(item) uit.
#
# ##### Samenvatting
# - **if --**		Voert iets uit als een voorwaarde klopt	&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`if leeftijd >= 18:`
# - **else --**		Wat te doen als de voorwaarde niet klopt	`else:`
# - **elif --**		Extra controle tussen if en else	&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`elif leeftijd >= 13:`
# - **for loop--**	Herhaal iets voor elk item in een lijst &nbsp;		`for item in lijst:`
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Enkele handige bewerkingen en operators die we nu niet behandelen:
#
# #### **Rekenkundige bewerkingen:**
# | Symbool | Naam             | Voorbeeld | Betekenis                 |
# | ------- | ---------------- | --------- | ------------------------- |
# | `+`     | optellen         | `5 + 3`   | geeft `8` terug           |
# | `-`     | aftrekken        | `10 - 4`  | geeft `6` terug           |
# | `*`     | vermenigvuldigen | `6 * 2`   | geeft `12` terug          |
# | `/`     | delen            | `8 / 2`   | geeft `4.0` terug (float) |
# | `//`    | gehele deling    | `9 // 2`  | geeft `4` terug (int)     |
# | `%`     | rest (modulo)    | `9 % 2`   | geeft `1` terug (de rest) |
# | `**`    | machtsverheffen  | `2 ** 3`  | geeft `8` terug (2³)      |
#
#
#
#
# #### **Vergelijkingsoperators**
# | Symbool | Betekenis             | Voorbeeld | Uitleg      |
# | ------- | --------------------- | --------- | ----------- |
# | `==`    | gelijk aan            | `5 == 5`  | True (waar) |
# | `!=`    | niet gelijk aan       | `5 != 3`  | True        |
# | `>`     | groter dan            | `6 > 4`   | True        |
# | `<`     | kleiner dan           | `3 < 7`   | True        |
# | `>=`    | groter of gelijk aan  | `5 >= 5`  | True        |
# | `<=`    | kleiner of gelijk aan | `4 <= 5`  | True        |
#
#
#
#
# #### **Logische operators**
# | Trefwoord | Betekenis        | Voorbeeld                  | Uitleg                              |
# | --------- | ---------------- | -------------------------- | ----------------------------------- |
# | `and`     | EN               | `True and False` → `False` | Alleen waar als **beide** waar zijn |
# | `or`      | OF               | `True or False` → `True`   | Waar als **één van beide** waar is  |
# | `not`     | NIET (omdraaien) | `not True` → `False`       | Keert het tegenovergestelde terug   |
#
#
#
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pandas (library)
# <img src="./images/pandas.png" alt="pandas image" width="600"/>
#
# #### **Wat is pandas en waarom is het handig?**
# Je hebt vast wel eens gewerkt met Excel of een CSV-bestand — bijvoorbeeld om een lijst bij te houden, cijfers te analyseren, of gegevens te filteren.
# Dat soort dingen kun je ook doen met Python, en daar is de library pandas perfect voor. pandas helpt je om:
# - Data uit Excel- of CSV-bestanden in te lezen.
# - Die data makkelijk te filteren, sorteren of bewerken.
# - Analyses en berekeningen te maken, zonder te hoeven klikken of slepen zoals in Excel.
# - Werken met grotere hoeveelheden data, veel sneller en efficiënter.
#
# Je kunt Pandas zien als een slimme databewerker in Python, die veel taken automatiseert die je normaal met de hand in Excel zou doen.
#
# #### **Hoe gebruik je pandas?**
#
# Voordat je Pandas kan gebruiken moet je het beschikbaar maken in je code. Dit doe je door het boven aan je code te importeren. Dit hebben wij straks vast gedaan voor jullie.
# ```Python
# import pandas as pd
# ```
#
# Vervolgens kan je je data importeren.
# ```Python
# df = pd.read_excel("C:/User/DivisionQ/Documenten/boeiende_data.xlsx", sheet_name=["Sheet1", "Sheet5"])
# ```
#
# Nu staat er in de `df` (afkorting voor "DataFrame") variabele een soort digitale tabel waar je in Python makkelijk mee kunt werken.
#
# #### **Pandas is een gereedschapskist vol kant-en-klare functies**
# Het mooie van pandas is dat je niet alles zelf hoeft te bedenken.
# Veel dingen die je vaak met data wilt doen, zoals filteren, groeperen of berekeningen maken, zijn al ingebouwd als functies die je direct kunt gebruiken. <br>
# Er zijn letterlijk honderden handige functies die je in een paar regels code kunt toepassen.
# Als je straks verder wilt kijken, vind je een overzicht van alle mogelijkheden in de officiële pandas documentatie.
#
# ____________________

# %% [markdown]
# ### **Hoe je AI kunt gebruiken om te coderen**
# Vroeger moest je als beginner in programmeren urenlang documentatie lezen, op forums zoeken of YouTube-video’s kijken om te begrijpen hoe je iets moest bouwen met code. Dat is natuurlijk nog steeds waardevol, maar dankzij AI is het nu veel makkelijker geworden om te beginnen.
#
# In Python bestaan er libraries: dat zijn verzamelingen van kant-en-klare functies en tools die je kunt gebruiken om snel iets te bouwen. Denk aan:
# * Tekst analyseren
# * Grafieken maken
# * Data lezen uit Excel
# * Kunstmatige intelligentie gebruiken
#
# Er zijn letterlijk duizenden libraries, elk met hun eigen mogelijkheden. Voor een beginner en ook gevorderde is het onmogelijk om alles te onthouden of snel ui te zoeken.
#
# #### **Hoe helpt AI hierbij?**
# Met tools zoals ChatGPT kun je:
#
# * Vragen hoe je iets moet doen
# * Vragen welke code je nodig hebt
# * De AI vragen om je code uit te leggen
# * Hulp krijgen bij foutmeldingen (errors)
#
# En het mooiste? Je hoeft niet alles zelf te begrijpen vanaf dag 1, je kunt stap voor stap leren terwijl je werkt.
#
# #### **Hoe stel je een goede prompt op?**
# AI is slim, maar jij moet duidelijk zijn over wat je wil.
# Hier zijn een paar tips voor goede prompts:
#
# **1. Wees specifiek**
#
# Slecht:
# > "Maak een programma"
#
# Beter:
# > "Maak een Python-programma dat een lijst met namen sorteert op alfabetische volgorde"
#
# ______________
# **2. Vertel welk probleem je hebt**
#
# Slecht:
# > "Mijn code werkt niet"
#
# Beter:
# > "Ik krijg een foutmelding bij het inlezen van een CSV-bestand met pandas. Dit is mijn code: …, en dit is mijn foutmelding: …"
#
# ______________
# **3. Kader je opdracht af**
#
# Slecht:
# > "Schrijf code voor een quiz"
#
# Beter:
# > "Schrijf een korte Python-quiz voor beginners met 3 meerkeuzevragen. Laat de gebruiker antwoorden invullen, en geef op het einde de score."
#
# ______________
# **4. Zeg wat je wel en niet wil**
# > "Gebruik geen geavanceerde libraries. Hou het simpel, ik ben een beginner."
#
# Of:
# > "Gebruik matplotlib om een simpele grafiek te maken van deze getallen: \\\[2, 4, 6, 8]"
# ______________
#
# #### **_Tip_: leer al doende**
# Gebruik ChatGPT als een coach aan je zijde. Vraag dingen zoals:
#
# * "Wat doet deze regel code?"
# * "Hoe zou ik dit zonder een for-loop kunnen doen?"
# * "Kun je deze code herschrijven zodat ik het begrijp?"
#
# Met AI hoef je als beginner niet meer te verdwalen in ingewikkelde documentatie.
# Je kunt gewoon vragen stellen alsof je het aan een leraar vraagt, en meteen aan de slag gaan.
# Onthoud wel, ChatGPT is slechts een tool welke je kant gebruiken maar vervangt niet het logisch nadenken en beredeneren.

# %% [markdown]
# ### Importeer libraries

# %%
# General imports
import os

# Imports for data handeling
import pandas as pd
from skimpy import clean_columns
import country_converter as coco

# Imports for plotting
import seaborn as sns
import matplotlib.pyplot as plt

# Settings for notebook
pd.set_option('display.max_rows', 40)
sns.set_style()

# %% [markdown]
# ### Data ophalen
#
# ##### Onze dataset bevat 31 kolommen:
# - **_year_**: Jaar waarop deze metingen van toepassing zijn.
# - **_area_**: Land waar de data vandaan komt.
# - **_savanna_fires_**: Emissies van branden in savanne-ecosystemen.
# - **_forest_fires_**: Emissies van branden in beboste gebieden.
# - **_fires_in_organic_soils_**: Emissies van branden in organische bodems.
# - **_fires_in_humid_tropical_forests_**: Emissies van branden in vochtige tropische bossen.
# - **_forestland_**: Land bedekt met bossen.
# - **_net_forest_conversion_**: Verandering in bosoppervlakte door ontbossing en herbebossing.
# - **_crop_residues_**: Emissies door het verbranden of afbreken van gewasresten na de oogst.
# - **_rice_cultivation_**: Emissies van methaan die vrijkomen tijdens de rijstteelt.
# - **_drained_organic_soils_(co2)_**: Emissies van koolstofdioxide die vrijkomen bij het ontwateren van organische bodems.
# - **_agrifood_systems_waste_disposal_**: Emissies van afvalverwerking binnen het agrovoedselsysteem.
# - **_ippu_**: Emissies van industriële processen en productgebruik (IPPU).
# - **_food_transport_**: Emissies van het transporteren van voedselproducten.
# - **_food_processing_**: Emissies van het verwerken van voedselproducten.
# - **_food_packaging_**: Emissies van de productie en verwijdering van voedselverpakkingsmaterialen.
# - **_food_retail_**: Emissies van de exploitatie van winkels die voedsel verkopen.
# - **_food_household_consumption_**: Emissies van voedselconsumptie op huishoudelijk niveau.
# - **_pesticides_manufacturing_**: Emissies afkomstig van de productie van pesticiden.
# - **_fertilizers_manufacturing_**: Emissies van de productie van meststoffen.
# - **_manure_applied_to_soils_**: Emissies van het aanbrengen van dierlijke mest op landbouwgronden.
# - **_manure_left_on_pasture_**: Emissies van dierlijke mest op weide- of grasland.
# - **_manure_management_**: Emissies van het beheren en behandelen van dierlijke mest.
# - **_on_farm_electricity_use_**: Elektriciteitsverbruik op boerderijen.
# - **_on_farm_energy_use_**: Energieverbruik op boerderijen.
# - **_rural_population_**: Aantal mensen dat in landelijke gebieden woont.
# - **_urban_population_**: Aantal mensen dat in stedelijke gebieden woont.
# - **_total_population_-_male_**: Totaal aantal mannelijke individuen in de bevolking.
# - **_total_population_-_female_**: Totaal aantal vrouwelijke individuen in de bevolking.
# - **_total_emission_**: Totale broeikasgasemissies uit verschillende bronnen.
# - **_average_temperature_°c_**: De gemiddelde temperatuurstijging (per jaar) in graden Celsius.
#
#
# Alle kolomnamen in de dataset zijn geschreven in [snake_case](https://nl.wikipedia.org/wiki/Snake_case) (kleine letters, met underscores ipv. spaties).
#
# **Opdracht 1**: Lees het csv bestand uit naar een tabel (pd.DataFrame), en sla dit tabel op in de `df` variabele.

# %%
pad_naar_data_file = os.path.join(os.getcwd(), "Agrofood_co2_emission.csv")
assert os.path.exists(pad_naar_data_file), "Het pad naar de data file bestaat niet"

df = pd.read_csv(pad_naar_data_file)  # Read the data from file to a Dataframe
df = clean_columns(df, replace={})

# %% [markdown]
# #### We voegen zelf ook nog 4 kolommen toe
# - **_continent_**: Continent waar dit gebied zich bevindt.
# - **_subregion_**: (Verenigde Naties) subregio waar dit gebied zich bevindt.
# - **_total_population_**: Som van de mannelijke en vrouwelijke bevolking.
# - **_emission_per_capita_**: Totale emissie gedeeld door de totale bevolking van een gebied.

# %%
# Maak je geen zorgen over dit code blok.
# Hier voegen we 4 kolommen toe aan de DataFrame, maar omdat sommige oude landen
# benamingen niet door alles ondersteunt worden moeten we deze eerst corrigeren.
manual_country_fixes = {
    'Belgium-Luxembourg': 'Belgium',
    'Channel Islands': 'United Kingdom',
    'China, Taiwan Province of': 'Taiwan',
    'Netherlands Antilles (former)': 'Netherlands',
    'Pacific Islands Trust Territory': 'Micronesia',
    'Serbia and Montenegro': 'Serbia', 
    'USSR': 'Russia',
    'Yugoslav SFR': 'Serbia',  
}

# Voeg de "continent" en "subregion" kolom toe. Dit doen we om de 236 landen te categoriseren.
cc = coco.CountryConverter()
df['area'] = df['area'].replace(manual_country_fixes)
df["continent"] = cc.convert(names=df["area"], to="continent")
df["subregion"] = cc.convert(names=df["area"], to="UNregion")
assert len(df[df['continent'] == 'not found']['area'].unique()) == 0 
assert len(df[df['subregion'] == 'not found']['area'].unique()) == 0 

# Voeg een "total_population" kolom toe als een som van mannelijke en vrouwelijke populaties.
# Daarna voegen we een kolom toe "emission_per_capita" waar we de totale emissies delen door de totale populatie van een land.
df["total_population"] = df["total_population_male"] + df["total_population_female"]
df["emission_per_capita"] = df["total_emission"] / df["total_population"]

# %% [markdown]
# ## Bekend worden met de data
#
# Voordat je analyse doet op je data is het belangrijk dat je bekend bent met je data.
# - Zijn er kolommen waar veel waardes missen?
# - Zijn er kolommen die overbodig zijn omdat ze altijd het zelfde zijn?
# - Wat is de correlatie tussen verschillende kolommen?
# - etc.
#
# **Opdracht 2**: print de eerste 5 rijen van de tabel.

# %%
display(df.head(5))

# %%
# Dit code blok maakt een tabel met vier kolommen: "Data Type", "Unieke Waardes", "Null Waardes" en "Non-null Waardes".
#
# - Data Type:          De type van de data in deze kolom (integer, string, etc.)
# - Unieke Waardes:     Hoeveel verschillende waardes er in totaal vorkomen in deze kolom
# - Null Waardes:       Hoevaak deze kolom is leeg gelaten in een rij
# - Non-null Waardes:   Hoevaak deze kolom wel is ingevuld in een rij

dtypes = df.dtypes 
missing_counts = df.isnull().sum()
non_null_counts = df.notnull().sum()
unique_counts = df.nunique()
summary = pd.DataFrame({
    "Data Type": dtypes,
    "Unieke Waardes": unique_counts,
    "# Null Waardes": missing_counts,
    "# Non-null Waardes": non_null_counts,
}).sort_values(by='# Null Waardes', ascending=False)
display(summary)

# %% [markdown]
# **Opdracht 3**: Bereken voor elke kolom statestieken over de verdeling van je data. (Denk aan de mean en standaarddeviatie)
#
# _Hint_: Als iets te veel werk lijkt voor iets simpels, is er waarschijnlijk een functie voor in pandas.

# %%
display(df.describe())

# %%
# In dit code blok doen we de correlatie matrix plotten. Laat je niet afschrikken als het er moeilijk uitziet, 
# met hulp van je digitale coach ChatGPT en als je er rustig functie voor functie over heen gaat zal je zien dat het niet zo ingewikkeld is.
#
# In ons geval zijn correlaties in de tekstvelden niet intressant, maar als je een categorie zou hebben
# (bijvoorbeeld een multiple choice vraag) dan zou je deze eerst moeten encoden naar nummers. Dit kan je ook automatisch laten doen.

figuur = plt.figure(figsize=(19, 15))  # Zet de groote van het figuur

# Maak de correlation matrix, en zet de kolom namen langs de randen
plt.matshow(
    df.drop(labels=["area", "continent", "subregion"], axis=1).corr(),
    fignum=figuur.number,
)
plt.xticks(
    range(df.select_dtypes(["number"]).shape[1]),
    df.select_dtypes(["number"]).columns,
    fontsize=14,
    rotation=90,
)
plt.yticks(
    range(df.select_dtypes(["number"]).shape[1]),
    df.select_dtypes(["number"]).columns,
    fontsize=14,
)

# Zet de legenda naast het plot, en geef het plot een titel
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title("Correlation Matrix", fontsize=18)
plt.show()

# %% [markdown]
# ## Data analyse
#
# In Python zijn kan je gemakkelijke veel grafieken maken. Hieronder is een voorbeeld te zien met hoeveel de verschillende continenten bijdroegen aan de totale CO2 uistoot over de jaren heen.

# %%
# In did code blok maken we een grafiek dat de bijdrage van verschillende continenten aan de totale CO2
# uitstoot laat zien over de jaren heen.

# Groepeer de rijen van de tabel op basis van "year" en "continent"
groep_jaar_continent = (
    df.groupby(["year", "continent"])["total_emission"].sum().unstack(fill_value=0)
)

# Om de stapel volgorde in de grafiek wat mooier te maken sorteren we op de 
# waardes van het laatste jaar. Zo zal de grootste uitstooter boven staan.
sorted_subregions = groep_jaar_continent.iloc[-1].sort_values().index.tolist()
grouped_year_sorted = groep_jaar_continent[sorted_subregions]

# Plot de grafiek.
fig, ax = plt.subplots(figsize=(20, 10))
ax.stackplot(
    grouped_year_sorted.index,
    grouped_year_sorted.T.values,
    labels=grouped_year_sorted.columns,
)

# Voeg een titel, assen titels en een legenda toe aan de grafiek.
plt.title("Totale emissies over de jaren per continent")
plt.xlabel("Jaar")
plt.ylabel("Totale Emissies")
plt.legend(title="Subregion", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.show()

# %% [markdown]
# Van hier verder gaan we alleen nog met data van Europa werken.
#
# **Opdracht 4**: Maak een tabel aan met alleen de gegevens van Europa er in en sla deze op in de `df_europe` variabele. Als je dit hebt gedaan, doe dan ook even checken of het gelukt is ;)

# %%
df_europe = df[df["continent"] == "Europe"]
assert df_europe["continent"].nunique() == 1

# %%
pp = sns.jointplot(data=df_europe, x="food_household_consumption", y="agrifood_systems_waste_disposal", hue="subregion", height=7)

# %% [markdown]
# Nu Jullie wat voorbeelden hebben gezien van wat je allemaal kan mogen jullie zelf aan de slag.
#
# **Opdracht 5**: bezoek de [Matplotlib site](https://matplotlib.org/stable/plot_types/index.html) of de [Seaborn site](https://seaborn.pydata.org/examples/index.html) en maak zelf een plot van de data, zie je nog ergens interresante relaties.
#
# _Hint_: Om autocomplete te gebruiken druk je `Tab`.
